# %%
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver

# %%
driver_path = 'C:/games/chromedriver'
web_driv = webdriver.Chrome(executable_path = driver_path)
search_url = "https://myanimelist.net/animelist/Shishere?status=2"
web_driv.get(search_url)

# %%
url = web_driv.execute_script("return document.getElementsByTagName('html')[0].innerHTML")

# %%
print(url)
# Out:
# <head><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-P656DGV&amp;t=gtm2&amp;cid=522276118.1596345628"></script><script src="https://connect.facebook.net/signals/config/403179503706622?v=2.9.22&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.redditstatic.com/ads/pixel.js"></script><script async="" src="//c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" type="text/javascript" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
#   <meta name="referrer" content="default">
#
#   <style type="text/css">
#     body.ownlist {
#           background-image: url("https://cdn.myanimelist.net/s/common/uploaded_files/1455540188-934a8b8942494df1086f9402bbb5330b.png");
# ...

# %%
soup = BeautifulSoup(url,'html.parser')

# %%
soup.find_all('a')
# Out:
# [<a @click.prevent="closeAdvancedOptions" href="#" id="fancybox-close" style="display: block;"></a>,
#  <a @click="applyFilter()" class="btn-apply" href="javascript: void(0);">Apply</a>,
#  <a @click="clearFilter()" class="btn-clear" href="javascript: void(0);">Clear</a>,
#  <a class="username" href="/profile/Shishere">Shishere</a>,
#  <a href="javascript: void(0);" id="header-menu-button">
#              Anime List
#              <i class="fa fa-angle-down"></i>
#  </a>,
#  <a href="/login.php">Log in</a>,
#  <a href="/register.php">Create an Anime List</a>,
#  <a class="icon-menu manga-list" href="/mangalist/Shishere">
#  <svg class="icon icon-manga-list" height="20px" version="1.1" viewbox="0 0 22 20" width="22px">
#  <g>
# ...

# %%
for tags in soup.find_all('td', class_='data progress'):
    tag=tags.div['class']
    print(tag[0].split('-')[1])
# Out:
# 38101
# 34881
# 101
# 6987
# 8577
# 22147
# 30206
# 30056
# 6547
# 9062
# 11111
# 24833
# 36882
# 6347
# 8516
# 9471
# 31043
# 31964
# 33486
# 35262
# 36456
# 38408
# 36896
# 10719
# 14967
# 14027
# 21405
# 24913
# 38186
# 40004
# 39819
# 31478
# 32867
# 1689
# 12293
# 28999
# 39523
# 14741
# 15687
# 15879
# 16934
# 2167
# 4181
# 6351
# 4059
# 1575
# 2904
# 15037
# 20031
# 23383
# 12549
# 15325
# 14893
# 30127
# 26349
# 29067
# 11843
# 12893
# 2025
# 7338
# 6573
# 38656
# 1535
# 28223
# 38691
# 28121
# 37347
# 40064
# 6746
# 2924
# 226
# 31376
# 9367
# 18001
# 5114
# 24765
# 30544
# 34280
# 23289
# 37349
# 17895
# 37105
# 17729
# 13161
# 20583
# 28891
# 32935
# 40262
# 38883
# 34403
# 15809
# 15225
# 5630
# 6372
# 6637
# 11617
# 24703
# 31326
# 32215
# 34281
# 15451
# 30300
# 12729
# 13357
# 8074
# 9515
# 934
# 1889
# 3652
# 11061
# 12189
# 13469
# 7088
# 9041
# 18247
# 20045
# 33242
# 21653
# 10794
# 37210
# 35203
# 21327
# 37999
# 40591
# 34933
# 37086
# 8525
# 10080
# 10805
# ...

# %%
for name in soup.find_all("td",class_='data title clearfix'):
    print(name.a.text)
# Out:
# 5-toubun no Hanayome
# Aho Girl
# Air
# Aki-Sora
# Aki-Sora: Yume no Naka
# Amagi Brilliant Park
# Amagi Brilliant Park: Nonbirishiteiru Hima ga Nai!
# Amagi Brilliant Park: Wakuwaku Mini Theater - Rakugaki Backstage
# Angel Beats!
# Angel Beats! Specials
# Another
# Ansatsu Kyoushitsu
# Arifureta Shokugyou de Sekai Saikyou
# Baka to Test to Shoukanjuu
# Baka to Test to Shoukanjuu Ni!
# Baka to Test to Shoukanjuu: Matsuri
# Boku dake ga Inai Machi
# Boku no Hero Academia
# Boku no Hero Academia 2nd Season
# Boku no Hero Academia 2nd Season: Hero Note
# Boku no Hero Academia 3rd Season
# Boku no Hero Academia 4th Season
# Boku no Hero Academia the Movie 1: Futari no Hero
# Boku wa Tomodachi ga Sukunai
# Boku wa Tomodachi ga Sukunai Next
# Boku wa Tomodachi ga Sukunai: Relay Shousetsu wa Ketsumatsu ga Hanpanai
# Bokura wa Minna Kawai-sou
# Bokura wa Minna Kawai-sou: Hajimete no
# Bokutachi wa Benkyou ga Dekinai
# Bokutachi wa Benkyou ga Dekinai!
# ...

# %%
for anime_type in soup.find_all('td', class_='data type'):
    print(anime_type.text)
# Out:
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           OVA
#
#
#           OVA
#
#
#           TV
#
#
#           Special
#
#
#           Special
#
#
#           TV
#
#
#           Special
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           OVA
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           Special
#
#
#           TV
#
#
#           TV
#
#
#           Movie
#
#
#           TV
#
#
#           TV
#
#
#           OVA
#
#
#           TV
#
#
#           Special
#
#
#           TV
#
#
#           TV
#
#
#           OVA
#
#
#           TV
#
#
#           TV
#
#
#           Movie
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           TV
#
#
#           ONA
#
#
#           Special
#
#
#           Special
#
#
#           TV
#
#
#           TV
#
#
#           Special
#
#
#           Special
#
#
#           TV
#
#
#           TV
#
#
#           OVA
#
#
#           TV
#
#
# ...

# %%
for anime_name , anime_tag , anime_type1 in zip(soup.find_all("td",class_='data title clearfix'),soup.find_all('td', class_='data progress'),soup.find_all('td', class_='data type')):
    #print(anime_name.a.text)
    #print(anime_type1.text)
    tag1=anime_tag.div['class']
    tag=tag1[0].split('-')[1]
    
    anime_url = requests.get(f'https://myanimelist.net/anime/{tag}/{anime_name.a.text}')
    soup1 = BeautifulSoup(anime_url.content , 'html.parser')
    episodes = soup1.find('div', class_="spaceit").text.split('\n  ')[1]
    #print(episodes)
    for dur in soup1.find_all('div', class_="spaceit"):
        if(dur.span.text=='Duration:'):
            #print(dur.text.split('\n  ')[1])
            duration = dur.text.split('\n  ')[1]
            break 
            
    print(anime_name.a.text,anime_type1.text,episodes,duration)
# Out:
# 5-toubun no Hanayome
#           TV
#          12 24 min. per ep.
# Aho Girl
#           TV
#          12 12 min. per ep.
# Air
#           TV
#          12 24 min. per ep.
# Aki-Sora
#           OVA
#          1 21 min.
# Aki-Sora: Yume no Naka
#           OVA
#          2 25 min. per ep.
# Amagi Brilliant Park
#           TV
#          13 24 min. per ep.
# Amagi Brilliant Park: Nonbirishiteiru Hima ga Nai!
#           Special
#          1 23 min.
# Amagi Brilliant Park: Wakuwaku Mini Theater - Rakugaki Backstage
#           Special
#          7 4 min. per ep.
# Angel Beats!
#           TV
#          13 24 min. per ep.
# Angel Beats! Specials
#           Special
#          2 27 min. per ep.
# Another
#           TV
#          12 24 min. per ep.
# Ansatsu Kyoushitsu
#           TV
#          22 23 min. per ep.
# Arifureta Shokugyou de Sekai Saikyou
#           TV
#          13 23 min. per ep.
# Baka to Test to Shoukanjuu
#           TV
#          13 24 min. per ep.
# ...
